# %% [markdown]
# <a href="https://colab.research.google.com/github/Erickpython/kodeCamp_5X-MachineLearning/blob/main/LinearReression_GradientDescent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question 1: Linear Regression with Gradient Descent
#
# You have below loosely correlated values of X and Y in arrays. You are expected to write the code to carry out linear regression with gradient descent for the provided data. Ensure each step of the process is properly documented using a text block in your notebook just before the code block.
#
#
#
# Requirements:
#
#     Print out the MSE after each cycle of training.
#     Plot a graph of the cost function as training progresses.
#     Print out the final values of your model parameters, m and c.
#     Plot a scatter graph of the original X, Y values along with a line graph of the final linear model after training.
#
#
# X = [ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#      2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#      5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#      7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ]
#
# Y = [ 2.60943416,  1.76213705,  7.18511292,  9.40744522,  5.46635068,
#      8.6061673 , 13.30831239, 14.26225166, 16.70323979, 16.87285951,
#     22.17984858, 23.81874177, 24.23732455, 28.20185083, 28.72449237,
#     27.91299402, 32.21118578, 31.39802427, 36.91479534, 36.90014818]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Collecting data and turning it to numpy array

x = np.array([ 0. , 0.52631579, 1.05263158, 1.57894737, 2.10526316, 2.63157895, 3.15789474,
             3.68421053, 4.21052632, 4.73684211, 5.26315789, 5.78947368, 6.31578947,
              6.84210526, 7.36842105, 7.89473684, 8.42105263, 8.94736842, 9.47368421, 10. ])

y = np.array([ 2.60943416, 1.76213705, 7.18511292, 9.40744522, 5.46635068, 8.6061673 , 13.30831239,
             14.26225166, 16.70323979, 16.87285951, 22.17984858, 23.81874177, 24.23732455,
              28.20185083, 28.72449237, 27.91299402, 32.21118578, 31.39802427, 36.91479534, 36.90014818])

# %%
# initialize the parameters to be used in training the models
m = 0   # initial gradient
c = 0   # initial y intercept
lr = 0.001  # steps during model training
epochs = 1000   # number of itterarions - learning cycles
n = len(x)

# %%
# functions for predicting and mse

def predict(x, m, c):
  return x * m + c


def mse(y, y_pred):
  return np.mean((y - y_pred)**2)

# %%
# gradient
cost_history = []

for epoch in range (epochs):
  y_pred = predict(x, m, c)
  error = y - y_pred

  # gradients
  dm = (2/n) * np.dot(error, x)
  dc = (2/n) * np.sum(error)

  # update learning parameters
  m = m + lr * dm  # Corrected update rule
  c = c + lr * dc  # Corrected update rule

  # compute mse
  cost = mse(y, y_pred)
  cost_history.append(cost)

  # print mse after each epoch
  print(f"Epoch {epoch+1}: MSE = {cost:.4f}")
# Out:
# Epoch 1: MSE = 499.6112
# Epoch 2: MSE = 432.6182
# Epoch 3: MSE = 374.6628
# Epoch 4: MSE = 324.5257
# Epoch 5: MSE = 281.1522
# Epoch 6: MSE = 243.6298
# Epoch 7: MSE = 211.1693
# Epoch 8: MSE = 183.0878
# Epoch 9: MSE = 158.7945
# Epoch 10: MSE = 137.7784
# Epoch 11: MSE = 119.5974
# Epoch 12: MSE = 103.8690
# Epoch 13: MSE = 90.2625
# Epoch 14: MSE = 78.4914
# Epoch 15: MSE = 68.3083
# Epoch 16: MSE = 59.4988
# Epoch 17: MSE = 51.8778
# Epoch 18: MSE = 45.2848
# Epoch 19: MSE = 39.5812
# Epoch 20: MSE = 34.6470
# Epoch 21: MSE = 30.3784
# Epoch 22: MSE = 26.6856
# Epoch 23: MSE = 23.4910
# Epoch 24: MSE = 20.7273
# Epoch 25: MSE = 18.3364
# Epoch 26: MSE = 16.2680
# Epoch 27: MSE = 14.4786
# Epoch 28: MSE = 12.9306
# Epoch 29: MSE = 11.5913
# Epoch 30: MSE = 10.4327
# Epoch 31: MSE = 9.4304
# Epoch 32: MSE = 8.5633
# Epoch 33: MSE = 7.8131
# Epoch 34: MSE = 7.1641
# Epoch 35: MSE = 6.6026
# Epoch 36: MSE = 6.1168
# Epoch 37: MSE = 5.6965
# Epoch 38: MSE = 5.3329
# ...

# %%
# display final parameters
print(f"\nFinal Model Parameters:")
print(f"Slope (m) = {m:.4f}")
print(f"Intercept (c) = {c:.4f}")
# Out:
# Final Model Parameters:
# Slope (m) = 3.6749
# Intercept (c) = 0.9191

# %%
# plotting - cost function v training progress
plt.figure(figsize=(8,5))
plt.plot(range(len(cost_history)), cost_history, "b-")
plt.title("MSE OVER TRAINING ITTERATIONS")
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.grid(True)
plt.show()

# %%
# plotting the regression line v actual data
plt.figure(figsize=(10,6))
plt.scatter(x, y, color="red", label="Actual Data")
plt.plot(x, predict(x, m, c), color="blue", label="Regression Line")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.grid(True)
plt.show()
